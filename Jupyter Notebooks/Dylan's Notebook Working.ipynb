// %%
cout << "yup" << endl;
// Out:
// yup

// %%
gROOT->ProcessLine(".L /home/rj/app/lib/libRadioScatter.so");
gROOT->ProcessLine("#include </home/rj/app/include/RadioScatter/RadioScatter.hh>");
gROOT->ProcessLine("#include </home/rj/app/include/RadioScatter/RSEventSummary.hh>");
gROOT->ProcessLine("#include </home/rj/app/include/RadioScatter/RadioScatterEvent.hh>");
gROOT->ProcessLine("#include </home/rj/app/include/RadioScatter/TUtilRadioScatter.hh>");

// %%
//TFile *f = TFile::Open("/users/PAS0654/dfrikken/Pitzer/retAnalysis/RSOutfiles/angleMacroMonteCarlo/summaries/fullAngleMacroMonteCarloSummary.root");
//TFile *f = TFile::Open("/users/PAS0654/dfrikken/Pitzer/retAnalysis/RSOutfiles/angleMacroMonteCarlo/summaries/energyScaleFullAngleMonteCarloSummary.root");
TFile *f = TFile::Open("/home/rj/RadioScatter/doc/output_test_0MHz_10W_10ns_summary.root");


TTree *t = (TTree*)f->Get("sumTree");
auto sum = new RSEventSummary();
t->SetBranchAddress("summary",&sum);
t->SetMarkerStyle(8);
cout<< t->GetEntries()<< " entries in file"<<endl;
// Out:
// 10 entries in file

// %%
t->Show(0)
// Out:
// ======> EVENT:0
//  summary         = (RSEventSummary*)0x7f82896881d0
//  fUniqueID       = 0
//  fBits           = 50331648
//  direction       = TVector3
//  position        = TVector3
//  polarization    = TVector3
//  tx              = (vector<TLorentzVector>*)0x7f8289688258
//  rx              = (vector<TLorentzVector>*)0x7f8289688270
//  primaryEnergyG4 = 10000
//  sampleRate      = 10
//  nPrimaries      = 1e+09
//  txVoltageV      = 22.3607
//  txPowerW        = 10
//  freq            = 0.2
//  weight          = 1
//  totNScatterers  = 1.69492e+17
//  primaryParticleEnergy = 1e+19
//  inelasticity    = 1
//  ntx             = 1
//  nrx             = 3
//  evtNo           = 1
//  peakFreq        = (vector<vector<double> >*)0x7f82896882e8
//  peakV           = (vector<vector<double> >*)0x7f8289688300
//  effectiveCrossSection = (vector<vector<double> >*)0x7f8289688318
//  rms             = (vector<vector<double> >*)0x7f8289688330
//  duration        = (vector<vector<double> >*)0x7f8289688348
//  integratedPower = (vector<vector<double> >*)0x7f8289688360
//  peakPowerW      = (vector<vector<double> >*)0x7f8289688378
//  pathLengthM     = (vector<vector<double> >*)0x7f8289688390
//  angRVP          = (vector<vector<double> >*)0x7f82896883a8
//  angTVP          = (vector<vector<double> >*)0x7f82896883c0
//  angTVR          = (vector<vector<double> >*)0x7f82896883d8
//  beta            = (vector<vector<double> >*)0x7f82896883f0
//  delta           = (vector<vector<double> >*)0x7f8289688408
//  doppler         = (vector<vector<double> >*)0x7f8289688420

// %%
c1 = TUtilRadioScatter::canvas();

// %%
//%jsroot on
//c1->SetLogy(0);

//t->Draw("integratedPower[0][1]:direction.Phi()","","");
t->Draw("duration[0]:angRVP[0]:angTVP[0]","angTVP[0]>1.9 && (peakFreq[0]> .5 || peakFreq[0] <.4)","colz");
//c1->SaveAs("peakFreqVsAngles.jpg");
c1->Draw();

// %%
%jsroot off
c1->SetLogy(0);

//t->Draw("integratedPower[0][1]:direction.Phi()","","");
//t->Draw("angRVP[0]:peakFreq[0]:angTVP[0]","peakFreq[0]>.5 || peakFreq[0]<.4 && angRVP[0]>.8","colz");
//c1->SaveAs("peakFreqVsAngles.jpg");
t->Draw("integratedPower[0]:angRVP[0]:angTVP[0]","","colz");
c1->Draw();


c1->SetLogz(0);

// %%
%jsroot off
c1->SetLogy(0);

//t->Draw("integratedPower[0][1]:direction.Phi()","","");
//t->Draw("angRVP[0]:peakFreq[0]:angTVP[0]","peakFreq[0]>.5 || peakFreq[0]<.4 && angRVP[0]>.8","colz");
//c1->SaveAs("peakFreqVsAngles.jpg");
t->Draw("angRVP[0]:peakFreq[0]:angTVP[0]","","colz");
c1->Draw();

// %%
%jsroot on
c1->Clear();
t->Draw("angRVP[0]:angTVP[0]:peakV[0]");
//c1->SaveAs("tvrinFile.jpg");
c1->Draw();
// Out:
// <div id="root_plot_1669138378740"
//      style="width: 696px; height: 572px">
// </div>
// <script>
//
// function display_root_plot_1669138378740(Core) {
//    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.15,"fRightMargin":0.18,"fBottomMargin":0.12,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-1.14181325979863,"fY1":-1.16951836117787,"fX2":1.21244088483939,"fY2":1.12365490407386,"fXtoAbsPixelk":337.560049896288,"fXtoPixelk":337.560049896288,"fXtoPixel":295.635032260722,"fYtoAbsPixelk":280.280051022816,"fYtoPixelk":280.280051022816,"fYtoPixel":-249.43601456875,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-1.14181325979863,"fPixeltoXk":-1.14181325979863,"fPixeltoX":0.00338254905838796,"fAbsPixeltoYk":1.12365490407386,"fPixeltoYk":-1.16951836117787,"fPixeltoY":-0.00400904417002051,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-0.788675134594813,"fUymin":-0.894337567297406,"fUxmax":0.788675134594813,"fUymax":0.894337567297406,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TH3F","fUniqueID":0,"fBits":521,"fName":"htemp","fTitle":"angRVP[0]:angTVP[0]:peakV[0]","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":8,"fMarkerSize":1,"fNcells":10648,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"peakV[0]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1.2,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":20,"fXmin":0,"fXmax":2.8e-5,"fXbins":[],"fFirst":1,"fLast":20,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"angTVP[0]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":20,"fXmin":1.2,"fXmax":3.2,"fXbins":[],"fFirst":1,"fLast":20,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"angRVP[0]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":20,"fXmin":1.2,"fXmax":3,"fXbins":[],"fFirst":1,"fLast":20,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":0,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fBufferSize":4001,"fBuffer":{"$arr":"Float64","len":4001},"fBinStatErrOpt":0,"fStatOverflows":2,"fTsumwy":0,"fTsumwy2":0,"fTsumwxy":0,"fTsumwz":0,"fTsumwz2":0,"fTsumwxz":0,"fTsumwyz":0,"fArray":{"$arr":"Float32","len":10648}},{"_typename":"TPaveText","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":0,"fX1":-0.713785501950216,"fY1":0.972674311565593,"fX2":0.784413126990979,"fY2":1.11218904868231,"fX1NDC":0.181810344827586,"fY1NDC":0.934160843929211,"fX2NDC":0.818189655172414,"fY2NDC":0.995000004768372,"fBorderSize":0,"fInit" ...

// %%
t->Draw("duration[0]:angRVP[0]");
//c1->SetLog
c1->Draw();
// Out:
// <div id="root_plot_1669138383748"
//      style="width: 696px; height: 572px">
// </div>
// <script>
//
// function display_root_plot_1669138383748(Core) {
//    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.15,"fRightMargin":0.18,"fBottomMargin":0.12,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":0.652238799331183,"fY1":16.6153845812178,"fX2":3.63731344080258,"fY2":36.4871795896801,"fXtoAbsPixelk":-152.075947707963,"fXtoPixelk":-152.075947707963,"fXtoPixel":233.159998859167,"fYtoAbsPixelk":1050.26585217888,"fYtoPixelk":1050.26585217888,"fYtoPixel":-28.7845159310679,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":696,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":0.652238799331183,"fPixeltoXk":0.652238799331183,"fPixeltoX":0.00428890034694166,"fAbsPixeltoYk":36.4871795896801,"fPixeltoYk":16.6153845812178,"fPixeltoY":-0.0347409003644446,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":1.1,"fUymin":19,"fUxmax":3.1,"fUymax":34.5,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":1.1,"fY1":19,"fX2":3.1,"fY2":34.5,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH2F","fUniqueID":0,"fBits":521,"fName":"htemp","fTitle":"duration[0]:angRVP[0]","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":8,"fMarkerSize":1,"fNcells":1764,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":"angRVP[0]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":40,"fXmin":1.1,"fXmax":3.1,"fXbins":[],"fFirst":1,"fLast":40,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":"duration[0]","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":40,"fXmin":19,"fXmax":34.5,"fXbins":[],"fFirst":1,"fLast":40,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":0,"fTsumw":0,"fTsumw2":0,"fTsumwx":0,"fTsumwx2":0,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fBufferSize":3001,"fBuffer":{"$arr":"Float64","len":3001},"fBinStatErrOpt":0,"fStatOverflows":2,"fScalefactor":1,"fTsumwy":0,"fTsumwy2":0,"fTsumwxy":0,"fArray":{"$arr":"Float32","len":1764}},{"_typename":"TPaveText","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":0,"fX1":1.45872362057009,"fY1":35.1788373767112,"fX2":2.83082861956367,"fY2":36.3878207093939,"fX1NDC":0.270172413793103,"fY1NDC":0.93416084392921 ...

// %%
%jsroot off
t->GetEntry(8);
//t->SetMarkerStyle(8);
t->Draw("rx.X():rx.Y():rx.Z():angRVP[0]","","colz");
c1->Draw();

// %%
t->Draw("angTVP[0]:angTVR[0]");
c1->SetLogy(0);
c1->Draw();

// %%
t->Draw("direction.Z()");
c1->Draw();

// %%
c1->Clear();
//c1->SetLogz();
t->Draw("peakFreq[0]:angRVP[0]:angTVP[0]","","prof");
c1->Draw();

// %%
t->Draw("direction.X():direction.Y():direction.Z():peakFreq[0]");
c1->Draw();

// %%
%jsroot off
c1 = TUtilRadioScatter::canvas();

c1->SetLogz(0);
t->Draw("duration[0]:angRVP[0]");
c1->Draw();

// %%
%jsroot off
c1->Clear();
c1->SetLogy(0);
t->Draw("peakV[0]:fmod((angRVP[0]+(angTVP[0]-pi/2)), pi)","","");
c1->Draw();

//r+(90-t)
//fmod((90+angTVP),2pi)

// %%
%jsroot off
c1->Clear();
c1->SetLogz(0);
t->Draw("angTVP[0]:angRVP[0]:peakFreq","","colz");
c1->Draw();

// %%
%jsroot on
c1->Clear();
t->Draw("peakFreq[0]:angTVP[0]:angRVP[0]");
c1->SetLogy(0);
c1->Draw();

// %%
t->Draw("angTVR[0]:angRVP[0]:angTVP[0]");
c1->SetLogy(0);
c1->Draw();

// %%
t->Draw("doppler:TMath::Cos(beta[0]/2)*TMath::Cos(delta[0]):angTVR");
c1->Draw();

// %%
t->Show(0)

// %%
%jsroot off
t->Draw("peakFreq:angRVP:duration","","colz");
c1->Draw();
